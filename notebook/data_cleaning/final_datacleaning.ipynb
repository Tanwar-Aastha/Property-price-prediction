# %% [markdown]
# ## **Data Cleaning of the Merged Dataset**

# %%
# importing libraries
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# loading the dataset
data = pd.read_csv('../data/gurgaon_properties.csv')

# %%
data.head()
# Out:
#                                    property_name property_type  \
# 0  6 Bedroom House for sale in Sector 50 Gurgaon         house
# 1                3 BHK Flat in Sector 90 Gurgaon          flat
# 2                2 BHK Flat in sector 58 Gurgaon          flat
# 3                3 BHK Flat in Sector 67 Gurgaon          flat
# 4               3 BHK Flat in Sector 104 Gurgaon          flat
#
#                society  price      area  price_per_sqft  \
# 0          independent   5.00  215517.0           232.0
# 1    dlf regal gardens   1.29    1430.0          9020.0
# 2  ireo the grand arch   2.20    1375.0         16000.0
# 3  ireo victory valley   2.95    2436.0         12110.0
# 4     puri emerald bay   2.23    2250.0          9911.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                         Plot area 2(1011.71 sq.m.)        6         5
# 1  Super Built up area 1702(158.12 sq.m.)Built Up...        3         3
# ...

# %%
# checking the shape of the dataset
data.shape
# Out:
# (3973, 20)

# %%
# checking for the missing values
data.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               0
# price                20
# area                 20
# price_per_sqft       20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony             115
# additionalRoom        0
# address              11
# floorNum             21
# facing              873
# agePossession         1
# nearbyLocations     206
# description           0
# furnishDetails     1034
# features            709
# rating              450
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3973 entries, 0 to 3972
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3973 non-null   object
#  1   property_type    3973 non-null   object
#  2   society          3973 non-null   object
#  3   price            3953 non-null   float64
#  4   area             3953 non-null   float64
#  5   price_per_sqft   3953 non-null   float64
#  6   areaWithType     3973 non-null   object
#  7   bedRoom          3973 non-null   int64
#  8   bathroom         3973 non-null   int64
#  9   balcony          3858 non-null   object
#  10  additionalRoom   3973 non-null   object
#  11  address          3962 non-null   object
#  12  floorNum         3952 non-null   float64
#  13  facing           3100 non-null   object
#  14  agePossession    3972 non-null   object
#  15  nearbyLocations  3767 non-null   object
# ...

# %%
# getting a new column named 'sector'
data['property_name'].value_counts()
# Out:
# property_name
# 2 BHK Flat in Sohna                                                                      125
# 3 BHK Flat in Sector 102 Gurgaon                                                          76
# 3 BHK Flat in Sector 65 Gurgaon                                                           57
# 3 BHK Flat in Sector 92 Gurgaon                                                           53
# 3 BHK Flat in Sector 69 Gurgaon                                                           51
# 2 BHK Flat in Sector 85 Gurgaon                                                           49
# 3 BHK Flat in Sector 83 Gurgaon                                                           47
# 3 BHK Flat in Sector 81 Gurgaon                                                           45
# 3 BHK Flat in Sector 79 Gurgaon                                                           44
# 3 BHK Flat in Sector 109 Gurgaon                                                          44
# ...

# %%
data.insert(loc=3, column='sector', value= data['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
data.head()
# Out:
#                                    property_name property_type  \
# 0  6 Bedroom House for sale in Sector 50 Gurgaon         house
# 1                3 BHK Flat in Sector 90 Gurgaon          flat
# 2                2 BHK Flat in sector 58 Gurgaon          flat
# 3                3 BHK Flat in Sector 67 Gurgaon          flat
# 4               3 BHK Flat in Sector 104 Gurgaon          flat
#
#                society      sector  price      area  price_per_sqft  \
# 0          independent   Sector 50   5.00  215517.0           232.0
# 1    dlf regal gardens   Sector 90   1.29    1430.0          9020.0
# 2  ireo the grand arch   sector 58   2.20    1375.0         16000.0
# 3  ireo victory valley   Sector 67   2.95    2436.0         12110.0
# 4     puri emerald bay  Sector 104   2.23    2250.0          9911.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                         Plot area 2(1011.71 sq.m.)        6         5
# ...

# %%
data['sector'] = data['sector'].str.lower()

# %%
# cleaning the sector column
data['sector'].value_counts()
# Out:
# sector
# sohna                                                        163
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    104
# sector 69                                                     94
# sector 65                                                     90
# sector 81                                                     90
# sector 90                                                     90
# sector 109                                                    88
# sector 79                                                     80
# sector 83                                                     69
# sector 37d                                                    68
# sector 86                                                     68
# sector 104                                                    66
# ...

# %%
data['sector'] = data['sector'].str.replace('dharam colony','sector 12')
data['sector'] = data['sector'].str.replace('krishna colony','sector 7')
data['sector'] = data['sector'].str.replace('suncity','sector 54')
data['sector'] = data['sector'].str.replace('prem nagar','sector 13')
data['sector'] = data['sector'].str.replace('mg road','sector 28')
data['sector'] = data['sector'].str.replace('gandhi nagar','sector 28')
data['sector'] = data['sector'].str.replace('laxmi garden','sector 11')
data['sector'] = data['sector'].str.replace('shakti nagar','sector 11')

data['sector'] = data['sector'].str.replace('baldev nagar','sector 7')
data['sector'] = data['sector'].str.replace('shivpuri','sector 7')
data['sector'] = data['sector'].str.replace('garhi harsaru','sector 17')
data['sector'] = data['sector'].str.replace('imt manesar','manesar')
data['sector'] = data['sector'].str.replace('adarsh nagar','sector 12')
data['sector'] = data['sector'].str.replace('shivaji nagar','sector 11')
data['sector'] = data['sector'].str.replace('bhim nagar','sector 6')
data['sector'] = data['sector'].str.replace('madanpuri','sector 7')

data['sector'] = data['sector'].str.replace('saraswati vihar','sector 28')
data['sector'] = data['sector'].str.replace('arjun nagar','sector 8')
data['sector'] = data['sector'].str.replace('ravi nagar','sector 9')
data['sector'] = data['sector'].str.replace('vishnu garden','sector 105')
data['sector'] = data['sector'].str.replace('bhondsi','sector 11')
data['sector'] = data['sector'].str.replace('surya vihar','sector 21')
data['sector'] = data['sector'].str.replace('devilal colony','sector 9')
data['sector'] = data['sector'].str.replace('valley view estate','gwal pahari')

data['sector'] = data['sector'].str.replace('mehrauli  road','sector 14')
data['sector'] = data['sector'].str.replace('jyoti park','sector 7')
data['sector'] = data['sector'].str.replace('ansal plaza','sector 23')
data['sector'] = data['sector'].str.replace('dayanand colony','sector 6')
data['sector'] = data['sector'].str.replace('sushant lok phase 2','sector 55')
data['sector'] = data['sector'].str.replace('chakkarpur','sector 28')
data['sector'] = data['sector'].str.replace('greenwood city','sector 45')
data['sector'] = data['sector'].str.replace('subhash nagar','sector 12')

data['sector'] = data['sector'].str.replace('sohna road road','sohna road')
data['sector'] = data['sector'].str.replace('malibu town','sector 47')
data['sector'] = data['sector'].str.replace('surat nagar 1','sector 104')
data['sector'] = data['sector'].str.replace('new colony','sector 7')
data['sector'] = data['sector'].str.replace('mianwali colony','sector 12')
data['sector'] = data['sector'].str.replace('jacobpura','sector 12')
data['sector'] = data['sector'].str.replace('rajiv nagar','sector 13')
data['sector'] = data['sector'].str.replace('ashok vihar','sector 3')

data['sector'] = data['sector'].str.replace('dlf phase 1','sector 26')
data['sector'] = data['sector'].str.replace('nirvana country','sector 50')
data['sector'] = data['sector'].str.replace('palam vihar','sector 2')
data['sector'] = data['sector'].str.replace('dlf phase 2','sector 25')
data['sector'] = data['sector'].str.replace('sushant lok phase 1','sector 43')
data['sector'] = data['sector'].str.replace('laxman vihar','sector 4')
data['sector'] = data['sector'].str.replace('dlf phase 4','sector 28')
data['sector'] = data['sector'].str.replace('dlf phase 3','sector 24')

data['sector'] = data['sector'].str.replace('sushant lok phase 3','sector 57')
data['sector'] = data['sector'].str.replace('dlf phase 5','sector 43')
data['sector'] = data['sector'].str.replace('rajendra park','sector 105')
data['sector'] = data['sector'].str.replace('uppals southend','sector 49')
data['sector'] = data['sector'].str.replace('sohna','sohna road')
data['sector'] = data['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
data['sector'] = data['sector'].str.replace('south city 1','sector 41')
data['sector'] = data['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
temp = data['sector'].value_counts()[data['sector'].value_counts()>=3]
data = data[data['sector'].isin(temp.index)]

# %%
data['sector'].value_counts()
# Out:
# sector
# sohna road                    163
# sector 102                    113
# sector 85                     110
# sector 92                     104
# sector 69                      94
# sector 90                      90
# sector 81                      90
# sector 65                      90
# sector 109                     88
# sector 79                      80
# sector 104                     73
# sector 83                      69
# sector 86                      68
# sector 37d                     68
# sector 50                      65
# sector 107                     60
# sector 108                     59
# sector 48                      58
# sector 95                      57
# sector 2                       57
# sector 56                      57
# sector 89                      56
# sector 70a                     55
# sector 70                      53
# sector 43                      53
# sector 37c                     53
# sector-33 sohna road           51
# ...

# %%
data['sector'] = data['sector'].str.replace('sector 95a','sector 95')
data['sector'] = data['sector'].str.replace('sector 23a','sector 23')
data['sector'] = data['sector'].str.replace('sector 12a','sector 12')
data['sector'] = data['sector'].str.replace('sector 3a','sector 3')
data['sector'] = data['sector'].str.replace('sector 110 a','sector 110')
data['sector'] = data['sector'].str.replace('patel nagar','sector 15')
data['sector'] = data['sector'].str.replace('a block sector 43','sector 43')
data['sector'] = data['sector'].str.replace('maruti kunj','sector 12')
data['sector'] = data['sector'].str.replace('b block sector 43','sector 43')

data['sector'] = data['sector'].str.replace('sector-33 sohna road','sector 33')
data['sector'] = data['sector'].str.replace('sector 1 manesar','manesar')
data['sector'] = data['sector'].str.replace('sector 4 phase 2','sector 4')
data['sector'] = data['sector'].str.replace('sector 1a manesar','manesar')
data['sector'] = data['sector'].str.replace('c block sector 43','sector 43')
data['sector'] = data['sector'].str.replace('sector 89 a','sector 89')
data['sector'] = data['sector'].str.replace('sector 2 extension','sector 2')
data['sector'] = data['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
data['sector'].value_counts()
# Out:
# sector
# sohna road                    163
# sector 102                    113
# sector 85                     110
# sector 92                     104
# sector 69                      94
# sector 65                      90
# sector 81                      90
# sector 90                      90
# sector 109                     88
# sector 79                      80
# sector 33                      74
# sector 104                     73
# sector 83                      69
# sector 86                      68
# sector 43                      68
# sector 37d                     68
# sector 95                      66
# sector 50                      65
# sector 2                       65
# sector 89                      64
# sector 107                     60
# sector 108                     59
# sector 48                      58
# sector 56                      57
# sector 70a                     55
# sector 70                      53
# sector 37c                     53
# ...

# %%
data[data['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 568   4 BHK Flat in New Gurgaon          flat                    sare homes
# 1995  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 2084  2 BHK Flat in New Gurgaon          flat                   green court
# 3317  4 BHK Flat in New Gurgaon          flat                        dlf 76
#
#      sector  price    area  price_per_sqft  \
# 568     new   0.85  1776.0          4786.0
# 1995    new   0.67  1200.0          5583.0
# 2084    new   0.38   690.0          5507.0
# 3317    new   4.00  3500.0         11428.0
#
#                                 areaWithType  bedRoom  bathroom balcony  \
# 568      Super Built up area 1776(165 sq.m.)        4         4       3
# 1995  Super Built up area 1200(111.48 sq.m.)        2         2       2
# 2084           Carpet area: 690 (64.1 sq.m.)        2         2       1
# 3317        Carpet area: 3500 (325.16 sq.m.)        4         4       2
#
# ...

# %%
# replacing the values 'new' to their actual sector
data.loc[568,'sector'] = 'sector 37'
data.loc[1995,'sector'] = 'sector 92'
data.loc[2084,'sector'] = 'sector 90'
data.loc[3317,'sector'] = 'sector 76'

# %%
data['sector'].value_counts()
# Out:
# sector
# sohna road                    163
# sector 102                    113
# sector 85                     110
# sector 92                     105
# sector 69                      94
# sector 90                      91
# sector 81                      90
# sector 65                      90
# sector 109                     88
# sector 79                      80
# sector 33                      74
# sector 104                     73
# sector 83                      69
# sector 86                      68
# sector 43                      68
# sector 37d                     68
# sector 95                      66
# sector 50                      65
# sector 2                       65
# sector 89                      64
# sector 107                     60
# sector 108                     59
# sector 48                      58
# sector 56                      57
# sector 70a                     55
# sector 70                      53
# sector 37c                     53
# ...

# %%
data[data['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 611   2 Bedroom House for sale in New Palam Vihar         house
# 1378                2 BHK Flat in New Palam Vihar          flat
# 2692                2 BHK Flat in New Palam Vihar          flat
# 3369                2 BHK Flat in New Palam Vihar          flat
# 3536  3 Bedroom House for sale in New Palam Vihar         house
#
#                   society        sector  price    area  price_per_sqft  \
# 611               my home  new sector 2   0.34   270.0         12592.0
# 1378              my home  new sector 2   0.22   500.0          4400.0
# 2692  ompee k s residency  new sector 2   1.60   594.0         26936.0
# 3369              my home  new sector 2   0.28   884.0          3166.0
# 3536          independent  new sector 2   1.00  1137.0          8796.0
#
#                                            areaWithType  bedRoom  bathroom  \
# ...

# %%
data.loc[[611,1378,2692,3369,3536],'sector'] = 'sector 110'

# %%
# checking for the duplicate values in data
data.duplicated().sum()
# Out:
# np.int64(13)

# %%
data[data.duplicated()]
# Out:
#                                           property_name property_type  \
# 1563  4 Bedroom House for sale in C Block Sushant Lo...         house
# 1596     4 Bedroom House for sale in Sector 70A Gurgaon         house
# 1821      3 Bedroom House for sale in Sector 48 Gurgaon         house
# 2093     4 Bedroom House for sale in Sector 112 Gurgaon         house
# 2352            8 Bedroom House for sale in Palam Vihar         house
# 2469           12 Bedroom House for sale in DLF Phase 1         house
# 2735      4 Bedroom House for sale in Sector 55 Gurgaon         house
# 3087        6 Bedroom House for sale in Uppals Southend         house
# 3172         5 Bedroom House for sale in Greenwood City         house
# 3521            3 Bedroom House for sale in Palam Vihar         house
# 3523      4 Bedroom House for sale in Sector 86 Gurgaon         house
# 3683      4 Bedroom House for sale in Sector 48 Gurgaon         house
# ...

# %%
# removing columns (property_name, address, description, rating)
data.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
data.sample(10)
# Out:
#      property_type                                  society      sector  \
# 3485          flat                           suncity avenue  sector 102
# 3658          flat                       godrej nature plus   sector 33
# 3925          flat                orris aster court premier   sector 85
# 240          house             sushant lok 1 builder floors   sector 43
# 1317          flat                     emaar gurgaon greens  sector 102
# 3971          flat                             tulip violet   sector 69
# 740          house      international city by sobha phase 2  sector 109
# 381           flat                  shree vardhman victoria   sector 70
# 1979          flat                 signature andour heights   sector 71
# 1965         house  sare crescent parc royal greens phase 1   sector 92
#
#       price    area  price_per_sqft  \
# 3485   0.48   532.0          9022.0
# 3658   1.40  1500.0          9333.0
# 3925   1.25  2120.0          5896.0
# ...

# %%
# exporting the dataset
data.to_csv('../data/gurgaon_properties_cleaned(round1).csv',index=False)
